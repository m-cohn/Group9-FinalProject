# %% [markdown]
# ## Create Zipped Data
#
# Runs the Python notebooks needed to generate our audio data features. If you have already downloaded all the zip files from the README, you may skip this step.

# %%
# %run data_formatter_mfcc.ipynb
# %run data_formatter_spectro.ipynb
# %run data_formatter_spectro_augmen.ipynb

# %% [markdown]
# ## Run Logistic Regression Models
#
# Trains logistic regression models on both the original and augmented data. After determining the best model for each data set, prints the accuracy and training time in seconds. Creates plots showing coefficients and their magnitudes.

# %%
import logres as lr

lr.run_augmented_data('mel_spectro_data_min_max_norm_augmented.npz')
# Out:
# (1359, 1, 128, 709)
# (1359,)
# New shape for each image (128, 709)
# (1223, 90752)
# (136, 90752)
# (1223,)
# (136,)
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [CV 1/5] END ...........................C=0.001;, score=0.576 total time=   0.8s
# [CV 2/5] END ...........................C=0.001;, score=0.576 total time=   1.0s
# [CV 3/5] END ...........................C=0.001;, score=0.576 total time=   0.8s
# [CV 4/5] END ...........................C=0.001;, score=0.578 total time=   0.8s
# [CV 5/5] END ...........................C=0.001;, score=0.574 total time=   1.0s
# [CV 1/5] END ............................C=0.01;, score=0.567 total time=   1.1s
# [CV 2/5] END ............................C=0.01;, score=0.584 total time=   1.1s
# [CV 3/5] END ............................C=0.01;, score=0.584 total time=   1.1s
# [CV 4/5] END ............................C=0.01;, score=0.590 total time=   0.9s
# [CV 5/5] END ............................C=0.01;, score=0.574 total time=   1.0s
# [CV 1/5] END .............................C=0.1;, score=0.661 total time=   1.3s
# [CV 2/5] END .............................C=0.1;, score=0.682 total time=   1.3s
# [CV 3/5] END .............................C=0.1;, score=0.678 total time=   1.3s
# [CV 4/5] END .............................C=0.1;, score=0.648 total time=   1.3s
# [CV 5/5] END .............................C=0.1;, score=0.643 total time=   1.1s
# [CV 1/5] END ...............................C=1;, score=0.690 total time=   2.1s
# [CV 2/5] END ...............................C=1;, score=0.694 total time=   2.3s
# [CV 3/5] END ...............................C=1;, score=0.657 total time=   1.9s
# [CV 4/5] END ...............................C=1;, score=0.672 total time=   2.3s
# [CV 5/5] END ...............................C=1;, score=0.631 total time=   2.3s
# [CV 1/5] END ..............................C=10;, score=0.673 total time=   2.7s
# [CV 2/5] END ..............................C=10;, score=0.682 total time=   3.1s
# [CV 3/5] END ..............................C=10;, score=0.620 total time=   2.7s
# [CV 4/5] END ..............................C=10;, score=0.660 total time=   3.0s
# [CV 5/5] END ..............................C=10;, score=0.635 total time=   3.1s
# [CV 1/5] END ..............................C=20;, score=0.665 total time=   3.1s
# [CV 2/5] END ..............................C=20;, score=0.682 total time=   3.0s
# [CV 3/5] END ..............................C=20;, score=0.620 total time=   2.7s
# [CV 4/5] END ..............................C=20;, score=0.648 total time=   2.8s
# [CV 5/5] END ..............................C=20;, score=0.639 total time=   2.7s
# [CV 1/5] END ..............................C=50;, score=0.665 total time=   3.1s
# [CV 2/5] END ..............................C=50;, score=0.682 total time=   3.3s
# [CV 3/5] END ..............................C=50;, score=0.612 total time=   3.0s
# [CV 4/5] END ..............................C=50;, score=0.635 total time=   2.8s
# [CV 5/5] END ..............................C=50;, score=0.631 total time=   3.6s
# Accuracy:  0.6691176470588235
# Time to train logistic regression: 78.43004655838013 seconds

# %% [markdown]
# ## Run Neural Networks
#
# Trains neural networks on both the original and augmented data. After training is done, prints the accuracy and training time (in seconds). Displays plots with the curves of both the training and validation accuracy for each epoch.
