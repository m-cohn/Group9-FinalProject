# %%
# %reload_ext autoreload
# %autoreload 2

# %%
# import statements
import dagshub as dh
import pandas as pd
import sklearn.svm as sk

# %%
data = pd.read_csv("speech-accent-archive\speakers_all.csv")
print(f"{data.shape[0]} rows, {data.shape[1]} columns") # delete later
# Out:
# 2172 rows, 12 columns

# %%
# Check out the dataset - delete later
data.head(10)
# Out:
#     age  age_onset              birthplace  filename native_language     sex
# 0  24.0       12.0         koussi, senegal   balanta         balanta    male  \
# 1  18.0       10.0          buea, cameroon  cameroon        cameroon    male
# 2  48.0        8.0  hong, adamawa, nigeria  fulfulde        fulfulde    male
# 3  42.0       42.0   port-au-prince, haiti   haitian         haitian    male
# 4  40.0       35.0   port-au-prince, haiti   haitian         haitian    male
# 5  43.0       41.0   port-au-prince, haiti   haitian         haitian    male
# 6  21.0       21.0   port-au-prince, haiti   haitian         haitian    male
# 7  54.0       51.0   port-au-prince, haiti   haitian         haitian  female
# 8  18.0       16.0      ouanaminthe, haiti   haitian         haitian  female
# 9  73.0        5.0  pepeekeo, hawai'i, usa   hawai'i         hawai'i    male
#
#    speakerid   country  file_missing?  Unnamed: 9  Unnamed: 10 Unnamed: 11
# ...

# %%
# Import our svm code
import svm
